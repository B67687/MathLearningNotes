# %% [markdown]
# ## Pascal's Triangle
#
# This is the Pascal's Triangle:
#
# $$
# pascals triangle
# $$
#
# Each number, bar `1`, is equal to the 2 numbers right above it added together
#
# This all is fine and dandy but why do is `1` an exception?
# - It is the starting point so we say, but shouldn't it be 0, why can 1 defy the rule of addition?
#
# We also know of its relevance in binomial distribution such that each row corresponds to the coefficients of each term in a binomial expansion
#
# And that the coefficients is also expressed in terms of choice, in forms like `2C1`, `4C3`, `8C2`
#
# So what gives?
# - How come Pascal's Triangle corresponds to choice?
# - Doesn't that mean all of the numbers can be expressed in terms of choice?
# - Does this bring about a earlier premise?
#
# Let's find out
#
# $$
# nchoosek notation, where n is the size, k is the number of choose
# $$
#
# If we choose less than nothing, there is no way. The premise of choosing is to find ways to group things together `(k)` out of some big pile of things `n`, to group less than nothing, is not possible.
#
# If we choose nothing, there is exactly 1 way, to choose nothing. Nothing else, except to choose a set of 0 things, can be done
#
# If we choose from `1` to `n`, then we have choice, some number > 1
#
# If we choose more than `n`, then there is no way. Because there is no way to choose more than the total.

# %% [markdown]
# Now that we know of these general patterns, we can rebuild the pascals triangle from the ground up
#
# To start off, we have nothing, thus to start building the triangle is to start choosing.
#
# From nothing, we can only choose nothing
#
# $$
# 0choose0 = 1
# $$
#
# Now that we have 1 thing, we have 1 more option to choose. We can choose nothing `i.e. 0` or we can choose `1`.
# - Thus this is `2` options total
#
# $$
# 0choose0 = 1
# 1choose0 = 1 1choose1 = 1
# $$
#
# We may continue this pattern of choosing from the previous choices so on and so forth
#
# $$
# 0choose0 = 1
# 1choose0 = 1 1choose1 = 1
# 2choose0 = 1 2choose1 = 2 2choose2 = 1
# 3choose0 = 1 3choose1 = 3 3choose2 = 3 3choose3 = 1
# $$
#
# How exactly we calculate the choices is explained in combinations and permutations chapter
#
# But what relevance does combination have to do with addition?
#
# Why does
#
# $$
# 0choose0 = 1chooose0 = 1choose1 = nchoose0 = nchoose1
# $$
#
# Why does
#
# $$
# 1choose0 + 1choose1 = 2choose1, 2choose1 + 2choose2 = 3choose2 etc etc
# $$
#
# There seems to be no relevance?

# %% [markdown]
# There is
#
# When we add one more thing to the total, we have 2 choices for that new thing, either it is chosen as part of the choice, or it is not chosen as part of the choice.
#
# Take an example
#
#
# From a premise of 7 choose 2, if we have one more thing, we have 8 choose 2
# Now either the 8th choice is chosen as part of the 2 choices, or it is not chosen
#
# If it is chosen: then the rest of the original 7 has to choose 1
# i.e. 1choose1 then 7choose1 -> 1choose1 7choose1
#
# If it is not chosen: then the rest of the original 7 has to choose 2
# i.e. 1choose0 then 7choose2 -> 1choose0 7choose2
#
# These 2 situations are both part of the new 8 choose 2.
#
# Thus
#
# $$
# 8choose2 = 1choose1 7choose1 + 1choose0 7choose2
# $$
#
# Let us test it on choosing 0 things
#
# From a premise of 7choose0, if we have one more thing, we have 8 choose 0
# Now the 8th choice is definitely not chosen, because the we are choosing no things.
# -> `0`
# Hence from the remaining original 7 things, to choose 0 things, there is only 1 way
# -> `7choose0`
#
# Thus
#
# $$
# 8choose0 = 0 + 7choose0 = 1
# $$
#
# And since we are choosing no things, even if there is no things in the first place, there is one way to choose nothing.
# Thus there is exactly 1 way for anything to choose 0
#
# What if we want to choose everything? How can that we explained in this way?
#
# Let us start from the premise of 7choose8, if we have one more thing, we have 8choose8
# Now we have 2 choices for the 8th choice, either it is chosen or it is not:
#
# If it is chosen: then the rest of the original 7 has 7 choices left
# i.e. 1choose1 then 7choose7 -> 1choose1 times 7choose7
#
# If it is not chosen: then the rest of the original 7 has 8 choices left
# i.e. 1choose0 then 7choose8 -> 1choose0 times 7choose8
#
# $$
# 8choose8 =  1choose1 times 7choose7 + 1choose0 times 7choose8
# $$
#
# We know that 7choose7 is 1, because if we choose everything, there is also only 1 way to do it
# We also know that 7choose8 is 0, because we cannot choose more than what we have
#
# Thus
#
# $$
# 8choose8 =  1choose1 times 7choose7 + 1choose0 times 7choose8
# ... = 1choose1 (1) + 1choose0 (0)
# ... = 1(1) + 1(0)
# ... = 1
# $$
#
# We can extend this explanation to positive integer n, and 0, choose itself, to be equals to 1.
#
# Thus we have explained through this continuation method of how n choose n equals to 1
#
# We can generalise the process of increasing the total choices into this, where `n` is the total number of things and we choose `m` items from it
#
# ##
# nchoosem => n+1choosem = 1choose1 nchoosem-1 + 1choose0 nchoosem = nchoosem-1 + nchoosem
# ##
#
# We can thus also generalise for any nchoosem is thus
#
# ##
# nchoosem = n-1choosem-1 + nchoosem = 1choose1 n-1choosem-1 + 1choose0 nchoosem
# ##

# %% [markdown]
# Lets test this again on the extreme cases
#
# When n choose 0,
#
# $$
# n choose 0 = 1choose1 x (n-1)choose-1 + 1choose0 x (n-1)choose0 = (n-1)choose-1 + (n-1)choose0 = 0 + 1 = 1
# $$
#
# When n choose n,
#
# $$
# n choose n = 1choose1 x (n-1)choose(n-1) + 1choose0 x (n-1)choose(n) = (n-1)choose(n-1) + (n-1)choose(n) = 1 + 0 = 1
# $$

# %% [markdown]
# ## Conclusion
#
# Therefore, in conclusion, we start from choice to generate the tree of combinations
#
# 0choose0 = 1
# 1choose0 = 1 1choose1 = 1
# 2choose0 = 1 2choose1 = 2 2choose2 = 1
# 3choose0 = 1 3choose1 = 3 3choose2 = 3 3choose3 = 1
# ...
#
# And through the principle of addition
# nchoosem to n+1choosem = 1choose1 nchoose(m-1) + 1choose0 nchoosem = nchoose(m-1) + nchoosem
#
# We get the property of the 2 numbers on top added together equals the number below it
#
# And thus we get the simplified version, known as the pascals triangle
#
# 1
# 11
# 121
# 1331
# ...
#
# This version cannot explain how 1 just comes about.
# And it is also simplified such tha
