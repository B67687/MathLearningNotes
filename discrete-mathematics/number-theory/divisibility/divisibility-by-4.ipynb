# %% [markdown]
# # The Composition of a Number
#
# $$
# \text{Number} = \underbrace{\overline{k \space m \space \cdots \space c \space b \space a}}_{\text{n places}} =
# \space \underline{k \cdot 10^{n-1}} +
# \underline{m \cdot 10^{n-2}} +
# \cdots +
# \underline{c \cdot 10^{2}} +
# \underline{b \cdot 10^{1}} +
# \underline{a \cdot 10^{0}}
# $$
#
# Lets look into the `powers of 10`

# %% [markdown]
# # Factoring Powers of 10
#
# Lets start from $10^0$
# - Which equals `1`
#
# $$
# 10^{0} = 1
# $$
#
# We cannot `partition` nor `factor` this that so lets move on to $10^1$
#
# ## Intentional Partitioning
#
# Notice that `10` can be `partitioned` into a `quotient that contains 4`, and the `remainder that is 2`
#
# $$
# \boxed{ \phantom{\big(} 10 = \underline{4 \cdot 2 + 2} \phantom{\big)} }
# $$
#
# If we move on to the `next power of 10`, we multiply by `10` to get this
#
# $$
# 100 = 4 \cdot 20 + 2 \cdot \boxed{10}
# $$
#
# Noticing the `10` in the partition, we can split it like how we did before
#
# $$
# 100 =  4 \cdot 20 + \underline{2 \space \big( 4 \cdot 2 + 2 \big)}
# $$
#
# And then regroup by `4`
#
# $$
# \begin{align}
#     100 &= \textcolor{lightgray}{4 \cdot 20}  + 4 \space (2 \cdot 2) + 2 \cdot 2 \\
#     &= \textcolor{lightgray}{4 \cdot 20} + 4 \cdot 4 + 4 \cdot 1 \\
#     &= 4 \space (20 + 4 + 1) \\
#     &= 4 \cdot 25
# \end{align}
# $$
#
# Thus,
#
# $$
# \boxed{
#     \phantom{\big(} 100 = \underline{4 \cdot 25} \phantom{\big)}
# }
# $$
#
# This works when we move on to the next power,
#
# $$
# \boxed{ \phantom{\big(} 1000 = \underline{4 \cdot 250} \phantom{\big(}}
# $$
#
# And the next one,
#
# $$
# \boxed{ \phantom{\big(} 10000 = \underline{4 \cdot 2500} \phantom{\big(}}
# $$
#
# ## Generalisation of Such Partitioning
#
# Thus, we get this pattern that replicates itself from the `2nd power onwards` up to some `n`
#
# $$
# \begin{align}
#     100 &= 4 \cdot 25 \\
#     1000 &= 4 \cdot 250 \\
#     10000 &= 4 \cdot 2500 \\
#     &\vdots \\
#     10^n &= 4 \space \big( 25 \cdot 10^{n-2} \big)
# \end{align}
# $$

# %% [markdown]
# # Going by the Structure
#
# Lets look back at the number again
#
# $$
# \text{Number} = \underbrace{\overline{k \space m \space \cdots \space c \space b \space a}}_{\text{n places}} =
# \space \underline{k \cdot 10^{n-1}} +
# \underline{m \cdot 10^{n-2}} +
# \cdots +
# \underline{c \cdot 10^{2}} +
# \underline{b \cdot 10^{1}} +
# \underline{a \cdot 10^{0}}
# $$
#
# ## Divisible by Place
#
# Since we know that every `power of 10` from the `2nd power onwards` will be `divisible by 4`
#
# $$
# \text{Number} = \underbrace{\overline{k \space m \space \cdots \space c \space \textcolor{lightgray}{b \space a}}}_{\text{n places}} =
# \space \underline{k \cdot 10^{n-1}} +
# \underline{m \cdot 10^{n-2}} +
# \cdots +
# \underline{c \cdot 10^{2}} \textcolor{lightgray}{+
# \underline{b \cdot 10^{1}} +
# \underline{a \cdot 10^{0}}}
# $$
#
# We just need to check whether the number up to the `tens place` is `divisible by 4`
#
# $$
# \text{Number} = \underbrace{\overline{\textcolor{lightgray}{k \space m \space \cdots \space c} \space b \space a}}_{\text{n places}} =
# \textcolor{lightgray}{\space \underline{k \cdot 10^{n-1}} +
# \underline{m \cdot 10^{n-2}} +
# \cdots +
# \underline{c \cdot 10^{2}}} +
# \underline{b \cdot 10^{1}} +
# \underline{a \cdot 10^{0}}
# $$

# %% [markdown]
# # Divisibility Rule 1
#
# Thus, to determine if the whole number is `divisible by 4`,
#
# $$
# \textbf{The number up to the tens place has to be a multiple of 4}
# $$

# %% [markdown]
# ---
#
# ### **Lets try factoring instead and see if there is another way to tell**
#
# ---

# %% [markdown]
# # Factoring the Number
#
#
# Lets look back at the number again
#
# $$
# \text{Number} = \underbrace{\overline{k \space m \space \cdots \space c \space b \space a}}_{\text{n places}} =
# \space \underline{k \cdot 10^{n-1}} +
# \underline{m \cdot 10^{n-2}} +
# \cdots +
# \underline{c \cdot 10^{2}} +
# \underline{b \cdot 10^{1}} +
# \underline{a \cdot 10^{0}}
# $$
#
# Since we know this
# - Where `n` increases from `2`
#
# $$
# 10^{n} = 4 \space \big( 25 \cdot 10^{n-2} \big)
# $$
#
# We factor it in
#
# $$
# \text{Number} =
# k \biggr( 4 \space \big( 25 \cdot 10^{n-3} \big) \biggr) +
# m \biggr( 4 \space \big( 25 \cdot 10^{n-4} \big) \biggr) +
# \cdots +
# c \Biggr( 4 \space \big( 25 \cdot 10^0 \big)  \Biggr) +
# b \Biggr( 4 \cdot 2 + 2 \Biggr) +
# a
# $$
#
# Let all the `25` times `powers of 10` be expressed like so
#
# $$
# q_{n} = 25 \cdot 10^{n}
# $$
#
# Then we have,
#
# $$
# \text{Number} =
# k \biggr( 4 \space q_{n-3} \biggr) +
# m \biggr( 4 \space q_{n-4} \biggr) +
# \cdots +
# c \Biggr( 4 \space q_{0}  \Biggr) +
# b \Biggr( 4 \cdot 2 + 2 \Biggr) +
# a
# $$
#
# Split the expression with `b` into a part with multiple of `4` and the other part without
#
# $$
# \textcolor{lightgray}{\text{Number} =
# k \biggr( 4 \space q_{n-3} \biggr) +
# m \biggr( 4 \space q_{n-4} \biggr) +
# \cdots +
# c \Biggr( 4 \space q_{0} \Biggr)} +
# b \Biggr( 4 \cdot 2 \Biggr) +
# 2b \textcolor{lightgray}{+
# a}
# $$
#
# And factor out the constant `4` and we get
#
# $$
# \boxed{
#     \text{Number} =
#     4 \biggr(
#     kq_{n-3} +
#     mq_{n-4} +
#     \cdots +
#     cq_{0} +
#     2b
#     \biggr) +
#     2b +
#     a
# }
# $$

# %% [markdown]
# # Analysis of Remainder
#
# Thus, we see that `the quotient` of the number is a `multiple of 4`
# - Thus making it `divisible by 4`
#
# $$
# \textcolor{lightgray}{\text{Number} =}
#     4 \biggr(
#     kq_{n-3} +
#     mq_{n-4} +
#     \cdots +
#     cq_{0} +
#     2b
#     \biggr) \textcolor{lightgray}{+
#     2b +
#     a}
# $$
#
# Thus for the `whole number to be divisible by 4`,  the `remainder` also has to be a `multiple of 4`
#
# $$
# \textcolor{lightgray}{\text{Number} =
#     4 \biggr(
#     kq_{n-3} +
#     mq_{n-4} +
#     \cdots +
#     cq_{0} +
#     2b
#     \biggr)} +
#     2b +
#     a
# $$

# %% [markdown]
# # Divisibility Rule 2
#
# Thus, to determine if the `whole number is divisible by 4`,
#
# $$
# \textbf{The sum of: } \underline{\textbf{Twice of its 2nd last digit}} \textbf{ plus its } \underline{\textbf{last digit}} \textbf{, must be divisible by 4}
# $$

# %% [markdown]
# ---
#
# **There is also another way to look at it**
#
# ---

# %% [markdown]
# # Composite Numbers
#
# `4` is a `composite number` that is made up of `two 2s`
#
# $$
# 4 = 2^{2}
# $$
#
# That means as long as a number is `divisible by 2 twice`, it is `divisible by 4`
#
# $$
# \underline{\text{Divisible by 4}} = \boxed{\text{Divisible by 2 twice}}
# $$
#
# We have already `derived the conditions` for `divisibility by 2` in a previous `jupyter notebook`
#
# Thus, lets just move it here
#
# ## Divisibility by 2
#
# In order for a number to be `divisible by 2`, it has to fulfil this condition:
#
# $$
# \textbf{The digit in the ones place has to be either of: 0, \ 2, \ 4, \ 6, \ 8, i.e. an even number}
# $$
#
# ## Divisibility by 4
# Thus, in order for a number to be `divisible by 4`
#
# $$
# \text{The digit in the ones place of number that fulfils has to be either of: 0, \ 2, \ 4, \ 6, \ 8 after }
# $$
#
# In other words
# > If the **sum of all the digits** is divisible by 3，and the **sum of all the digits of that sum is also divisible by 3**，then the number is divisible by 9。
