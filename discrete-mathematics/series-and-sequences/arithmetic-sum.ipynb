# %% [markdown]
# # Deriving the Arithmetic Sum
#
# Find the sum of 1 to 100:
#
# $$
# 1 + 2 + \cdots + 99 + 100
# $$
#
# We find that
#
# $$
# \begin{align*}
#     1 + 100 &= 101 \\
#     2 + 99 &= 101 \\
#     3 + 98 &= 101 \\
#     4 + 97 &= 101 \\
#     5 + 96 &= 101 \\
#     \vdots \\
#     49 + 52 &= 101 \\
#     50 + 51 &= 101 \\
# \end{align*}
# $$
#
# Each pair equidistant from the ends of the sum, sum up to the same number, all the way down to the last pair
#
# Therefore, this pairing allows us to formulate that the sum of numbers `1` to `100` is
#
# $$
# (1 + 100) \times \text{Number of pairs} \\
# $$
#
# $$
# \text{or}
# $$
#
# $$
# (2 + 99) \times \textcolor{lightgray}{\text{Number of pairs}} \\
# $$
#
# $$
# \text{or}
# $$
#
# $$
# (3 + 98) \times \textcolor{lightgray}{\text{Number of pairs}} \\
# $$
#
# $$
# \vdots
# $$
#
# Since `k` includes `1` and `n`, we will have to shift what we call the `start` and the `end`
# - `start` shifts from `1` to `0`, such that a displacement of `1` from the start gets us to `1`
# - `end` shifts from `n` to `n+1`, such that a displacement of `1` from the end get us to `n`
#
# $$
# \big[ k + (n+1)-k \big] \times \text{Number of pairs}
# $$
#
# Expand and Simplify
#
# $$
# (n + 1) \times \textcolor{lightgray}{\text{Number of pairs}}
# $$
#
# Thus
#
# $$
# (n + 1) \times \text{Number of pairs}
# $$
#
# ---
# #### One might incorrectly access the meaning of k-th number from the start and end as this
# - Letting the `start` be `1` and the `end` be `n`
#
# $$
# \big[ (1 + k) + (n-k) \big] \times \text{Number of pairs}
# $$
#
# Expand and Simplify
#
# $$
# \big[ 1 + k + n - k \big] \times \textcolor{lightgray}{\text{Number of pairs}}
# $$
#
# $$
# (1 + n) \times \textcolor{lightgray}{\text{Number of pairs}}
# $$
#
# Thus
#
# $$
# (1 + n) \times \text{Number of pairs}
# $$
#
# #### We get the same answer, but this is due to its inherent symmetry, that masks the error in interpretation, and fallacy in our logical reasoning.
#
# - Lets continue
#
# ---
#
# We have this
#
# $$
# (n + 1) \times \text{Number of pairs}
# $$
#
# The number of pairs is the just `total terms` divided by `2` (a pair)
#
# $$
# (n+1) \times \dfrac{n}{2}
# $$
#
# Which is
#
# $$
# \dfrac{n(n+1)}{2}
# $$
#
# And thus we arrive at this formula
#
# $$
# \text{Sum from 1 to 100 is } \quad \dfrac{n(n+1)}{2}
# $$
#
# ---
#
# But why does pairing work in the first place? Let's dig deeper to uncover more basic truths that underlie arithmetic sums like this

# %% [markdown]
# # Understanding Arithmetic Series Sums Through Symmetry of Averages
#
# The sum of an arithmetic series is a classic result in mathematics, often proven using the method attributed to Gauss, which pairs terms from the ends of the sequence.
# For example, to sum the numbers $1 + 2 + \cdots + 100$, Gauss paired terms from the ends ($1 + 100$, $2 + 99$, etc.) to derive the total
#
# But lets explain it from an alternative perspective, revealing why this pairing works fundamentally
#
# ## Averages as Symmetry on a Number Line
#
# Let’s rethink what an average means for numbers in an arithmetic sequence, where each term increases by a common difference.
# - Instead of just “sum divided by the number of terms,”
# - We can see the average as the central point around which the numbers are symmetrically balanced.
#
# Consider any term:
# $$
# \large\boxed{a}
# $$
#
# If we move a some distance `d` away from the term, we can get to 2 points
# $$
# \large{\boxed{a - d} \longleftarrow a \longrightarrow \boxed{a + d}}
# $$
#
# Notice that the way we built this means `a` is average of the 2 points, because we have moved the same amount both left and right with reference to `a`
#
# $$
# \colorbox{lightgray}{If we keep moving the same amount in both directions, `a` will keep being the average}
# $$

# %% [markdown]
# ## Recursive Construction
#
# Lets further illustrate this by imagining the above as a term itself, `b`:
#
# $$
# \large{b : \boxed{
#     a - d \longleftarrow a \longrightarrow a + d
#     }
# }
# $$
#
# Let's move `d` away from `b` from both sides
#
# $$
# \large{
#     \boxed{b - d} \longleftarrow b \longrightarrow \boxed{b + d}
# }
# $$
#
# ... which is equivalent to this:
#
# $$
# \large{ \boxed{a - 2d} \longleftarrow \boxed{a - d \longleftarrow a \longrightarrow a + d} \longrightarrow \boxed{a + 2d}}
# $$
#
# $$
# \large{ \boxed{a - 2d} \longleftarrow \boxed{a - d} \longleftarrow a \longrightarrow \boxed{a + d} \longrightarrow \boxed{a + 2d}}
# $$
#
# Notice because we can keep doing this, `a` is guaranteed to always be in the centre as we always move at **equal magnitudes** but in **opposite directions**
#
# $$
# \large{
#     \dots \longleftarrow \boxed{a - d} \longleftarrow \boxed{a - d} \longleftarrow a \longrightarrow \boxed{a + d} \longrightarrow \boxed{a + 2d} \longrightarrow \dots
# }
# $$
#
# It thus can also allow for pairs equidistant to the midpoint to not exist, because `d` can be smaller or bigger, the midpoint stays constant always regardless.
#
# $$
# \large{
#     \dots \longleftarrow \boxed{a - 2d} \textcolor{darkgray}{\longleftarrow \boxed{a - d}} \longleftarrow a \longrightarrow \textcolor{darkgray}{\boxed{a + d} \longrightarrow} \boxed{a + 2d} \longrightarrow \dots
# }
# $$
#
# In essence it all depends on how small or big the choice of `d` is.
#
#
# $$
# \colorbox{lightgray}{The centre (which is also the average), a, can always be derived from any 2 points equidistant from a}
# $$

# %% [markdown]
# ## Finding an Anchor
#
# From `a`:
# $$
# \dfrac{(a - 0) + (a + 0)}{2} = a
# $$
#
# $$
# \dfrac{(a - d) + (a + d)}{2} = a
# $$
#
# $$
# \dfrac{(a - 2d) + (a + 2d)}{2} = a
# $$
#
# $$
# \vdots
# $$
#
# $$
# \dfrac{\boxed{a - (n - 1)d} + \boxed{a + (n - 1)d}}{2} = a
# $$
#
# But equally, any 2 points equidistant from the furthest points
#
# $$
# \dfrac{\boxed{a - (n - 1)d} + \boxed{a + (n - 1)d}}{2} = a
# $$
#
# $$
# \vdots
# $$
#
# $$
# \dfrac{(a - d) + (a + d)}{2} = a
# $$
#
# $$
# \dfrac{(a - 0) + (a + 0)}{2} = a
# $$
#
# Thus
#
# $$
# \colorbox{lightgray}{Since the first and last points always exist, we can always find the average of the whole sum by taking the average of the first and last points}
# $$
#
# - Even for sums with 1 term, whereby the first and last points are itself

# %% [markdown]
# # Finalise the Pattern
#
# Therefore, since the total of this series is:
#
# $$
# \text{Total } = \text{Average } \cdot \text{ Number of Terms}
# $$
#
# And on the average
#
# $$
# \textcolor{lightgray}{\text{Total } =} \text{Average } \textcolor{lightgray}{\cdot} \textcolor{lightgray}{\text{ Number of Terms}}
# $$
#
# It is
#
# $$
# \begin{align}
#     \text{Average of this series } &= \text{Average of the first and last term } \\
#     &= \dfrac{\text{first } + \text{ last}}{2}
# \end{align}
# $$
#
# Therefore
#
# $$
# \boxed{\text{Total } = \dfrac{\text{first } + \text{ last}}{2} \cdot \text{ Number of Terms}}
# $$
#
# ---

# %% [markdown]
# # How this relates to Arithmetic Sums
#
# ## Rebuilding any Arithmetic Sequence
# Consider the simple case:
# $$
# \boxed{a}
# $$
#
# In an arithmetic sequence, there is a common difference of `d`,
#
# Normally the sequence is built in one direction based off the base term `a`.
#
# In sum `S` with `n` terms:
#
# $$
# \begin{align}
#     &S_1 = a \\
#     &S_2 = a + \boxed{a + d} \\
#     &S_3 = a + \boxed{a + d} + \boxed{a + 2d} \\
#     &S_n = a + \boxed{a + d} + \boxed{a + 2d} + \dots + \boxed{a + (n - 1)d}
# \end{align}
# $$
#
# An equal way of viewing the arithmetic sequence is to build from both sides:
#
# $$
# \begin{array}{cc}
#     S_1 = & a \\
#     S_3 = & \boxed{a - d} + a + \boxed{a + d} \\
#     S_5 = & \boxed{a - 2d} + \boxed{a - d} + a + \boxed{a + d} + \boxed{a + 2d} \\
#     S_{2n-1} = & \boxed{a - \left( \dfrac{n - 1}{2} \right) d} + \dots + \boxed{a - 2d} + \boxed{a - d} + a + \boxed{a + d} + \boxed{a + 2d} + \dots + \boxed{a + \left( \dfrac{n - 1}{2} \right) d} \\
# \end{array}
# $$
#
#
# It seems that I am missing the series where there are even terms
#
# While conserving this structure, we can get the series of even terms:
#
# $$
# \begin{array}{cc}
#     S_2 = & \textcolor{lightgray}{a} \\
#     S_2 = & \boxed{a - d} + \textcolor{lightgray}{a} + \boxed{a + d} \\
#     S_4 = & \boxed{a - 2d} + \boxed{a - d} + \textcolor{lightgray}{a} + \boxed{a + d} + \boxed{a + 2d} \\
#     S_{2n} = & \boxed{a - \left( \dfrac{n}{2} \right) d} + \dots + \boxed{a - 2d} + \boxed{a - d} + \textcolor{lightgray}{a} + \boxed{a + d} + \boxed{a + 2d} + \dots + \boxed{a + \left( \dfrac{n}{2} \right) d} \\
# \end{array}
# $$
#
# Notice that the average doesn't exist as a term in sums with even number of terms

# %% [markdown]
# # Concluding the Pattern
#
# Therefore, for any number of terms, the average will always be `a`, and the total can be easily calculated as:
#
# $$
# \text{Arithmetic Sum } = \text{Average } \cdot \text{Number of Terms}
# $$
#
# Or like this:
#
# $$
# \text{Arithmetic Sum } = a \cdot n
# $$
#
# And since the average can always be calculated from the `first` and `last` terms
#
# $$
# \boxed{\text{Arithmetic Sum } = \dfrac{\text{first } + \text{ last}}{2} \cdot \text{ Number of Terms}}
# $$
#
#
# **Thus**:
#
# Let an arithmetic sequence be defined with:
# - **First term**: $a$
# - **Common difference**: $d$
# - **Number of terms**: $n$
# - **Terms**: $a, a + d, \ldots, a + (n-1)d$
# - **Sum**: $S_n = a + (a + d) + \cdots + (a + (n-1)d)$
#
# $$
# \begin{align}
#     S_n &= a \cdot n \\
#     &= \dfrac{\text{first} + \text{last}}{2} \cdot n \\
#     &= \dfrac{a + \biggr[ a + (n-1)d \biggr]}{2} \cdot n \\
#     &= \dfrac{2a + (n-1)d}{2} \cdot n \\
#     &= \dfrac{n}{2} \biggr[ 2a + (n-1)d \biggr]
# \end{align}
# $$
#
# Therefore, we get to our familiar formula for the arithmetic sum:
# $$
# \boxed{S_n = \dfrac{n}{2} \biggr[ 2a + (n-1)d \biggr]}
# $$

# %% [markdown]
# # Finding the Number of Terms in an Arithmetic Sequence
#
# Given any arithmetic sequence
#
# $$
# a_1 + (a_1 + d) + (a_1 + 2d) + \cdots + a_{n-1} + a_{n}
# $$
#
# The number of terms can be found as such
# - Take the difference between the last and first term,
# - Divide by the common difference to find how many terms to the last term from the first term,
# - Then add 1 to account for the first term.
#
# Given like this:
#
# $$
# \text{Number of Terms =} \space \dfrac{a_{n} - a_{1}}{d} + 1
# $$

# %% [markdown]
# # Application to the Sum of Arithmetic Sequence with Common Difference 1
#
# $\Huge{
# S_1 = 1 + 2 + 3 + \dots + n
# }$
#
# ### Applying the formula
# Now let's find its formula using the knowledge of Symmetric Averages
#
# The sequence $1, 2, 3, \dots, n$ has:
# - First term: $1$
# - Last term: $n$
# - Number of terms: $n$
#
# The sum of an arithmetic sequence is given by:
#
# $$
# \text{Total} = \text{Average} \cdot \text{Number of Terms}
# $$
#
# Calculate the average of the first and last terms:
#
# $$
# \text{Average} = \dfrac{\text{First} + \text{Last}}{2} = \dfrac{1 + n}{2}
# $$
#
# The number of terms is:
#
# $$
# \text{Number of terms} = n
# $$
#
# So the total sum is:
#
# $$
# \text{Total} = \left( \dfrac{1 + n}{2} \right) \cdot n = \dfrac{n(n + 1)}{2}
# $$
#
# Therefore:
#
# $$
# \boxed{S_1 = \dfrac{n(n + 1)}{2}}
# $$

# %% [markdown]
# # Gauss' Pair-Matching
#
# #### And this is why Gauss' Pair-Matching method works
#
# Write the sequence forward:
#
# $$
# S_n = 1 + 2 + 3 + \dots + (n - 1) + n
# $$
# Write the sequence in reverse:
#
# $$
# S_n = n + (n - 1) + \dots + 3 + 2 + 1
# $$
#
# Adding the two sequences term by term pairs the terms equidistant from the average:
#
# $$
# 2S_n = (1 + n) + (2 + (n - 1)) + \dots + ((n - 1) + 2) + (n + 1)
# $$
#
# Each pair `(as observed as well as proven)` sums to the same value:
#
# $$
# \textcolor{lightgray}{2S_n =} (1 + n) + (n + 1) + \dots + (n + 1) + (n + 1)
# $$
#
# There are $n$ terms in the original sequence, so there are $n$ pairs:
#
# $$
# 2S_n = \underbrace{(n + 1) + (n + 1) + \dots + (n + 1) + (n + 1)}_{\text{n pairs}}
# $$
#
# $$
# 2S_n = n \cdot (n + 1)
# $$
#
# Divide by 2:
#
# $$
# S_n = \dfrac{n \cdot (n + 1)}{2}
# $$
#
# Thus:
# $$
# \boxed{S_n = \dfrac{n(n + 1)}{2}}
# $$
